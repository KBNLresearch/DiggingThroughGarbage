# %% [markdown]
# # Instruction garbage detection models

# %%
import os
import sys
import pandas as pd

sys.path.append(os.path.abspath("*/Functions/"))

import adding_features

# %% [markdown]
# ## Prepare the data
#
# Load the data, split the data into seperate words. Apply the adding_features functions to add the features as used by the models

# %%
string1 = 'en graef lefle heeft by den paus van weghen keyserlijcke majesteyt om een half milioen gelt totten oorlogh gesolliciteert twelck den paus in bedencken genomen heeft om vranckrijck niet te offenderen'

# %%
string2 = "en 2aef seflc peeft bp ben pau ban toegpen bepfeclpche i3ajeftept om ten fjalf iilioen geit totten ologp gefolltct teert ttoclcft den pau in bedencben genomen ieefr0111 2ancbrpcb niet teoffendecen"

# %% [markdown]
# ## Run the model
# Unzip the models from the 'Models' folder. Load the desired model and run it on the dataset.

# %%
randomforest = pd.read_pickle("*/garbage_model_RandomForest.pkl")
